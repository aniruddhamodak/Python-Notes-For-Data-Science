# %% [markdown]
# <a href="https://colab.research.google.com/github/aniruddhamodak/Python-Notes-For-Data-Science/blob/master/15_Seaborn_Regression_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Plots
#
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the **lmplot()** function for now.
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore how this works:

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## lmplot()

# %%
# [4]
sns.lmplot(x='total_bill',y='tip',data=tips);

# %%
# [5]
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex');

# %%
# [6]
sns.lmplot(x='total_bill',y='tip',data=tips,palette="coolwarm");

# %% [markdown]
# ## Using a Grid
#
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
# [8]
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex');

# %%
# [9]
sns.lmplot(x='total_bill',y='tip',data=tips,row="sex",col="time");

# %%
# [10]
sns.lmplot(x='total_bill',y='tip',data=tips,col="day",palette="coolwarm");

# %% [markdown]
# ## Aspect and Size
#
# Seaborn figures can have their size and aspect ratio adjusted with the **size** and **aspect** parameters:

# %%
# [12]
sns.lmplot(x='total_bill',y='tip',data=tips,hue="sex",col="day",palette="coolwarm",aspect=0.4,size=5);
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
